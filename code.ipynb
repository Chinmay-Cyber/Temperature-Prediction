# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

data = pd.read_csv("data.csv", encoding="latin-1")

print(data.head())
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   °C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   °C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# 1  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2  1.494 -3.187  2.699  2.251 -0.323  2.705  0.086
# 3  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4  2.246 -0.076 -0.497  2.296  0.834  4.418  0.234
#
# [5 rows x 66 columns]

# %%
data=data.drop(columns=["Area Code","Months Code","Element Code","Unit"])
print(data.head())
# Out:
#           Area    Months             Element  Y1961  Y1962  Y1963  Y1964  \
# 0  Afghanistan   January  Temperature change  0.777  0.062  2.744 -5.232
# 1  Afghanistan   January  Standard Deviation  1.950  1.950  1.950  1.950
# 2  Afghanistan  February  Temperature change -1.743  2.465  3.919 -0.202
# 3  Afghanistan  February  Standard Deviation  2.597  2.597  2.597  2.597
# 4  Afghanistan     March  Temperature change  0.516  1.336  0.403  1.659
#
#    Y1965  Y1966  Y1967  ...  Y2010  Y2011  Y2012  Y2013  Y2014  Y2015  Y2016  \
# 0  1.868  3.629 -1.432  ...  3.601  1.179 -0.583  1.233  1.755  1.943  3.416
# 1  1.950  1.950  1.950  ...  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2 -0.096  3.397  0.296  ...  1.212  0.321 -3.201  1.494 -3.187  2.699  2.251
# 3  2.597  2.597  2.597  ...  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4 -0.909 -0.069 -0.759  ...  3.390  0.748 -0.527  2.246 -0.076 -0.497  2.296
#
#    Y2017  Y2018  Y2019
# 0  1.201  1.996  2.951
# 1  1.950  1.950  1.950
# 2 -0.323  2.705  0.086
# 3  2.597  2.597  2.597
# 4  0.834  4.418  0.234
#
# [5 rows x 62 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9656 entries, 0 to 9655
# Data columns (total 62 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Area     9656 non-null   object
#  1   Months   9656 non-null   object
#  2   Element  9656 non-null   object
#  3   Y1961    8287 non-null   float64
#  4   Y1962    8322 non-null   float64
#  5   Y1963    8294 non-null   float64
#  6   Y1964    8252 non-null   float64
#  7   Y1965    8281 non-null   float64
#  8   Y1966    8364 non-null   float64
#  9   Y1967    8347 non-null   float64
#  10  Y1968    8345 non-null   float64
#  11  Y1969    8326 non-null   float64
#  12  Y1970    8308 non-null   float64
#  13  Y1971    8303 non-null   float64
#  14  Y1972    8323 non-null   float64
#  15  Y1973    8394 non-null   float64
#  16  Y1974    8374 non-null   float64
#  17  Y1975    8280 non-null   float64
#  18  Y1976    8209 non-null   float64
#  19  Y1977    8257 non-null   float64
#  20  Y1978    8327 non-null   float64
#  21  Y1979    8290 non-null   float64
#  22  Y1980    8283 non-null   float64
#  23  Y1981    8276 non-null   float64
#  24  Y1982    8237 non-null   float64
#  25  Y1983    8205 non-null   float64
#  26  Y1984    8259 non-null   float64
#  27  Y1985    8216 non-null   float64
#  28  Y1986    8268 non-null   float64
#  29  Y1987    8284 non-null   float64
#  30  Y1988    8273 non-null   float64
#  31  Y1989    8257 non-null   float64
#  32  Y1990    8239 non-null   float64
#  33  Y1991    8158 non-null   float64
#  34  Y1992    8354 non-null   float64
#  35  Y1993    8315 non-null   float64
#  36  Y1994    8373 non-null   float64
#  37  Y1995    8409 non-null   float64
#  38  Y1996    8439 non-null   float64
#  39  Y1997    8309 non-null   float64
#  40  Y1998    8370 non-null   float64
#  41  Y1999    8324 non-null   float64
#  42  Y2000    8342 non-null   float64
#  43  Y2001    8241 non-null   float64
#  44  Y2002    8312 non-null   float64
#  45  Y2003    8390 non-null   float64
#  46  Y2004    8415 non-null   float64
#  47  Y2005    8424 non-null   float64
#  48  Y2006    8503 non-null   float64
#  49  Y2007    8534 non-null   float64
#  50  Y2008    8475 non-null   float64
#  51  Y2009    8419 non-null   float64
#  52  Y2010    8435 non-null   float64
#  53  Y2011    8437 non-null   float64
#  54  Y2012    8350 non-null   float64
#  55  Y2013    8427 non-null   float64
#  56  Y2014    8377 non-null   float64
#  57  Y2015    8361 non-null   float64
#  58  Y2016    8348 non-null   float64
#  59  Y2017    8366 non-null   float64
#  60  Y2018    8349 non-null   float64
#  61  Y2019    8365 non-null   float64
# dtypes: float64(59), object(3)
# memory usage: 4.6+ MB

# %%
data.describe()
# Out:
#              Y1961        Y1962        Y1963        Y1964        Y1965  \
# count  8287.000000  8322.000000  8294.000000  8252.000000  8281.000000
# mean      0.402433     0.315527     0.317393     0.269382     0.217839
# std       0.701567     0.713777     0.853133     0.749216     0.739418
# min      -4.018000    -5.391000    -8.483000    -7.309000    -4.728000
# 25%       0.057000    -0.033000     0.030250    -0.102500    -0.214000
# 50%       0.366000     0.333000     0.355000     0.326000     0.303000
# 75%       0.676500     0.627000     0.647750     0.609000     0.584000
# max       5.771000     4.373000     4.666000     5.233000     5.144000
#
#              Y1966        Y1967       Y1968        Y1969        Y1970  ...  \
# count  8364.000000  8347.000000  8345.00000  8326.000000  8308.000000  ...
# mean      0.376419     0.263239     0.24487     0.382172     0.365322  ...
# std       0.737370     0.725421     0.75490     0.725313     0.662412  ...
# min      -8.147000    -6.531000    -8.40700    -6.784000    -5.847000  ...
# 25%       0.055000    -0.169000    -0.16400     0.171000     0.094000  ...
# 50%       0.360000     0.313000     0.31200     0.385000     0.367000  ...
# 75%       0.660250     0.601000     0.59500     0.677000     0.642000  ...
# max       5.771000     4.768000     4.37300     4.411000     4.373000  ...
#
#              Y2010        Y2011        Y2012        Y2013        Y2014  \
# count  8435.000000  8437.000000  8350.000000  8427.000000  8377.000000
# mean      0.884504     0.768488     0.788930     0.829647     0.913872
# std       0.878303     0.750631     0.858586     0.713753     0.815933
# min      -6.072000    -4.854000    -5.785000    -3.642000    -5.367000
# 25%       0.392000     0.365000     0.372250     0.408500     0.418000
# 50%       0.771000     0.640000     0.651000     0.719000     0.745000
# 75%       1.276500     1.091000     1.108000     1.126000     1.190000
# max       7.190000     6.531000    10.826000     6.738000    11.759000
#
#              Y2015        Y2016        Y2017        Y2018        Y2019
# count  8361.000000  8348.000000  8366.000000  8349.000000  8365.000000
# mean      1.018816     1.081491     1.003342     1.010832     1.094599
# std       0.840189     0.877399     0.809800     0.872199     0.853953
# min      -4.068000    -3.306000    -3.584000    -2.216000    -2.644000
# 25%       0.437000     0.457000     0.443000     0.434000     0.455000
# 50%       0.858000     0.949000     0.865000     0.810000     0.939000
# 75%       1.389000     1.496000     1.364750     1.341000     1.508000
# max       7.590000    10.478000     7.389000     9.228000     7.215000
#
# [8 rows x 59 columns]

# %%
data.isnull().sum
# Out:
# <bound method DataFrame.sum of        Area  Months  Element  Y1961  Y1962  Y1963  Y1964  Y1965  Y1966  Y1967  \
# 0     False   False    False  False  False  False  False  False  False  False
# 1     False   False    False  False  False  False  False  False  False  False
# 2     False   False    False  False  False  False  False  False  False  False
# 3     False   False    False  False  False  False  False  False  False  False
# 4     False   False    False  False  False  False  False  False  False  False
# ...     ...     ...      ...    ...    ...    ...    ...    ...    ...    ...
# 9651  False   False    False  False  False  False  False  False  False  False
# 9652  False   False    False  False  False  False  False  False  False  False
# 9653  False   False    False  False  False  False  False  False  False  False
# 9654  False   False    False  False  False  False  False  False  False  False
# 9655  False   False    False  False  False  False  False  False  False  False
#
#       ...  Y2010  Y2011  Y2012  Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  \
# 0     ...  False  False  False  False  False  False  False  False  False
# 1     ...  False  False  False  False  False  False  False  False  False
# 2     ...  False  False  False  False  False  False  False  False  False
# 3     ...  False  False  False  False  False  False  False  False  False
# 4     ...  False  False  False  False  False  False  False  False  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9651  ...  False  False  False  False  False  False  False  False  False
# 9652  ...  False  False  False  False  False  False  False  False  False
# 9653  ...  False  False  False  False  False  False  False  False  False
# 9654  ...  False  False  False  False  False  False  False  False  False
# 9655  ...  False  False  False  False  False  False  False  False  False
#
#       Y2019
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9651  False
# 9652  False
# 9653  False
# 9654  False
# 9655  False
#
# [9656 rows x 62 columns]>

# %%
data_long = data.melt(
    id_vars=["Area","Months","Element"],
    var_name="Year",
    value_name="Temperature"
)
# melt reshapes the dataset we made a new dataset here named data_long

# %%
print(data_long.head())
# Out:
#           Area    Months             Element   Year  Temperature
# 0  Afghanistan   January  Temperature change  Y1961        0.777
# 1  Afghanistan   January  Standard Deviation  Y1961        1.950
# 2  Afghanistan  February  Temperature change  Y1961       -1.743
# 3  Afghanistan  February  Standard Deviation  Y1961        2.597
# 4  Afghanistan     March  Temperature change  Y1961        0.516

# %%
data_long['Year']=data_long['Year'].str.replace("Y","").astype(int)

# %%
print(data_long.head())
# Out:
#           Area    Months             Element  Year  Temperature
# 0  Afghanistan   January  Temperature change  1961        0.777
# 1  Afghanistan   January  Standard Deviation  1961        1.950
# 2  Afghanistan  February  Temperature change  1961       -1.743
# 3  Afghanistan  February  Standard Deviation  1961        2.597
# 4  Afghanistan     March  Temperature change  1961        0.516

# %%
data_long.isnull().sum
data_long=data_long.dropna()

# %%
from sklearn.preprocessing import LabelEncoder
le_area=LabelEncoder()
le_month=LabelEncoder()

data_long["Area"]=le_area.fit_transform(data_long["Area"])
data_long["Months"]=le_month.fit_transform(data_long["Months"])

# %%
X=data_long[['Area','Months','Year']]
Y=data_long['Temperature']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
# train the  model 
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import mean_absolute_error
prediction=model.predict(X_test)
mae=mean_absolute_error(y_test,prediction)
print(mae)
# Out:
# 0.5899184412627299

# %%
area = le_area.transform(["India"])
month = le_month.transform(["December"])

prediction = model.predict([[area[0], month[0], 2028]])

print(prediction[0])
# Out:
# 0.4703224999999995
